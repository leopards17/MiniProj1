# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/noahschutz/datascience/userssharedsdfschoolimprovement2010grants.csv")

# %% [markdown]
# ### Having imported our data, we need to take a look at it to see what we can extract from it.

# %%
print(data)
# Out:
#                                           School Name               City  \
# 0                   HOGARTH KINGEEKUK MEMORIAL SCHOOL           SAVOONGA
# 1                                     AKIACHAK SCHOOL           AKIACHAK
# 2                                      GAMBELL SCHOOL            GAMBELL
# 3                                BURCHELL HIGH SCHOOL            WASILLA
# 4                                        AKIAK SCHOOL              AKIAK
# 5                                      MIDVALLEY HIGH            WASILLA
# 6                                     TULUKSAK SCHOOL           TULUKSAK
# 7                         CAPITOL HEIGHTS JR HIGH SCH         MONTGOMERY
# 8                               LOWNDES CO MIDDLE SCH       FORT DEPOSIT
# 9                                  CENTRAL MIDDLE SCH           ROCKFORD
# 10                            BELLINGRATH JR HIGH SCH         MONTGOMERY
# 11                              HAYNEVILLE MIDDLE SCH         HAYNEVILLE
# 12                               SOUTHLAWN MIDDLE SCH         MONTGOMERY
# 13                            CONTINUOUS LEARNING CTR             MOBILE
# 14                            JACKSON-STEELE ELEM SCH         HAYNEVILLE
# 15                                MCINTYRE MIDDLE SCH         MONTGOMERY
# 16                                JOHN ESSEX HIGH SCH          DEMOPOLIS
# 17                                   CALHOUN HIGH SCH        LETOHATCHEE
# 18                              OSCEOLA MIDDLE SCHOOL            OSCEOLA
# 19                                   HALL HIGH SCHOOL        LITTLE ROCK
# 20                            ROSE CITY MIDDLE SCHOOL  NORTH LITTLE ROCK
# 21                           TRUSTY ELEMENTARY SCHOOL         FORT SMITH
# 22                              J.A. FAIR HIGH SCHOOL        LITTLE ROCK
# 23                                OSCEOLA HIGH SCHOOL            OSCEOLA
# 24                           CLOVERDALE MIDDLE SCHOOL        LITTLE ROCK
# 25                          GADSDEN ELEMENTARY SCHOOL            GADSDEN
# 26                            EAST VALLEY HIGH SCHOOL               MESA
# 27                           CRITTENTON YOUTH ACADEMY            PHOENIX
# 28                               ALCHESAY HIGH SCHOOL         WHITERIVER
# 29                             SAN CARLOS HIGH SCHOOL         SAN CARLOS
# ..                                                ...                ...
# 801                          WASHINGTON MIDDLE SCHOOL             YAKIMA
# 802  FOSTER & WILLIAMS HIGH SCHOOL OF THE VISUAL ARTS          MILWAUKEE
# 803                                       DUBOIS HIGH          MILWAUKEE
# 804                                       CUSTER HIGH          MILWAUKEE
# 805                     JAMES MADISON ACADEMIC CAMPUS          MILWAUKEE
# 806                                      VINCENT HIGH          MILWAUKEE
# 807                                     BAY VIEW HIGH          MILWAUKEE
# 808       DOWNTOWN INSTITUTE OF ARTS & LETTERS (DIAL)          MILWAUKEE
# 809                               SOUTH DIVISION HIGH          MILWAUKEE
# 810         MILWAUKEE AFRICAN AMERICAN IMMERSION HIGH          MILWAUKEE
# 811                WHS LAW EDUCATION & PUBLIC SERVICE          MILWAUKEE
# 812                           BRADLEY TECHNOLOGY HIGH          MILWAUKEE
# 813                                       HAMLIN PK-8             HAMLIN
# 814                             RIVERSIDE HIGH SCHOOL              BELLE
# 815                DODDRIDGE COUNTY ELEMENTARY SCHOOL         WEST UNION
# 816                            MOUNT VIEW HIGH SCHOOL              WELCH
# 817                            WEST HAMLIN ELEMENTARY        WEST HAMLIN
# 818                          MALDEN ELEMENTARY SCHOOL         CHARLESTON
# 819                   MARTINSBURG NORTH MIDDLE SCHOOL        MARTINSBURG
# 820                         SANDY RIVER MIDDLE SCHOOL           AVONDALE
# 821                   STONEWALL JACKSON MIDDLE SCHOOL         CHARLESTON
# 822                           EAST BANK MIDDLE SCHOOL          EAST BANK
# 823                        FRANKLIN ELEMENTARY CENTER        PARKERSBURG
# 824                               GUYAN VALLEY MIDDLE         BRANCHLAND
# 825                         CEDAR GROVE MIDDLE SCHOOL        CEDAR GROVE
# 826                            MOUNT HOPE HIGH SCHOOL         MOUNT HOPE
# 827                           GEARY ELEMENTARY SCHOOL          LEFT HAND
# 828                               TRIUMPH HIGH SCHOOL           CHEYENNE
# 829                     HEM JUNIOR/SENIOR HIGH SCHOOL              HANNA
# 830                             ROOSEVELT HIGH SCHOOL             CASPER
#
#     State                                  District Name 2010/11/Award Amount  \
# 0      AK                  BERING STRAIT SCHOOL DISTRICT           $471014.00
# 1      AK                         YUPIIT SCHOOL DISTRICT           $520579.00
# 2      AK                  BERING STRAIT SCHOOL DISTRICT           $449592.00
# 3      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $641184.00
# 4      AK                         YUPIIT SCHOOL DISTRICT           $399686.00
# 5      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $697703.00
# 6      AK                         YUPIIT SCHOOL DISTRICT           $427658.00
# 7      AL                              MONTGOMERY COUNTY           $110544.00
# 8      AL                                 LOWNDES COUNTY            $12973.00
# 9      AL                                   COOSA COUNTY           $199828.00
# 10     AL                              MONTGOMERY COUNTY           $165903.00
# 11     AL                                 LOWNDES COUNTY           $121657.00
# 12     AL                              MONTGOMERY COUNTY           $914557.00
# 13     AL                                  MOBILE COUNTY           $198953.00
# 14     AL                                 LOWNDES COUNTY           $118394.00
# 15     AL                              MONTGOMERY COUNTY           $143238.00
# 16     AL                                 MARENGO COUNTY           $151116.00
# 17     AL                                 LOWNDES COUNTY           $163619.00
# 18     AR                        OSCEOLA SCHOOL DISTRICT           $665000.00
# 19     AR                    LITTLE ROCK SCHOOL DISTRICT           $198728.00
# 20     AR                 N. LITTLE ROCK SCHOOL DISTRICT           $991451.00
# 21     AR                     FORT SMITH SCHOOL DISTRICT           $990135.00
# 22     AR                    LITTLE ROCK SCHOOL DISTRICT           $197012.00
# 23     AR                        OSCEOLA SCHOOL DISTRICT           $695000.00
# 24     AR                    LITTLE ROCK SCHOOL DISTRICT           $198783.00
# 25     AZ                    GADSDEN ELEMENTARY DISTRICT           $847003.00
# 26     AZ                         LEGACY EDUCATION GROUP           $381512.00
# 27     AZ  FLORENCE CRITTENTON SERVICES OF ARIZONA  INC.           $915959.00
# 28     AZ                    WHITERIVER UNIFIED DISTRICT           $812195.00
# 29     AZ                    SAN CARLOS UNIFIED DISTRICT           $928654.00
# ..    ...                                            ...                  ...
# 801    WA                         YAKIMA SCHOOL DISTRICT           $115268.00
# 802    WI                      MILWAUKEE SCHOOL DISTRICT             $5000.00
# 14   Transformation  570 FREEDOM RD\nHAYNEVILLE, AL 36040\n(32.304,...
# 15   Transformation  1220 HUGH ST\nMONTGOMERY, AL 36108\n(32.3603, ...
# 16   Transformation  70 HORNET DR\nDEMOPOLIS, AL 36732\n(32.4848, -...
# 17   Transformation  8213 COUNTY RD 33\nLETOHATCHEE, AL 36047\n(32....
# 18   Transformation  711 WEST LEE\nOSCEOLA, AR 72370\n(35.7002, -89...
# 19   Transformation  6700 H ST\nLITTLE ROCK, AR 72205\n(34.7605, -9...
# 20   Transformation  5500 LYNCH DR\nNORTH LITTLE ROCK, AR 72117\n(3...
# 21   Transformation  3300 HARRIS AVE\nFORT SMITH, AR 72904\n(35.412...
# 22   Transformation  13420 DAVID O DODD RD\nLITTLE ROCK, AR 72210\n...
# 23   Transformation  2800 WEST SEMMES\nOSCEOLA, AR 72370\n(35.7053,...
# 24   Transformation  6300 HINKSON RD\nLITTLE ROCK, AR 72209\n(34.67...
# 25   Transformation  18745 SOUTH GADSDEN ST\nGADSDEN, AZ 85336\n(32...
# 26       Turnaround  7420 EAST MAIN ST\nMESA, AZ 85207\n(33.4155, -...
# 27       Turnaround  715 WEST MARIPOSA ST\nPHOENIX, AZ 85013\n(33.5...
# 28   Transformation  200 FALCON WAY\nWHITERIVER, AZ 85941\n(33.8252...
# 29   Transformation  SAN CARLOS AVE\nSAN CARLOS, AZ 85550\n(33.3514...
# ..              ...                                                ...
# 801  Transformation  510 SOUTH 9TH ST\nYAKIMA, WA 98901\n(46.5986, ...
# 802         Closure  6700 NORTH 80TH ST\nMILWAUKEE, WI 53223\n(43.1...
# 803         Closure  4141 NORTH 64TH ST\nMILWAUKEE, WI 53216\n(43.0...
# 804         Restart  5075 NORTH SHERMAN BLVD\nMILWAUKEE, WI 53209\n...
# 805  Transformation  8135 WEST FLORIST AVE\nMILWAUKEE, WI 53218\n(4...
# 806  Transformation  7501 NORTH GRANVILLE RD\nMILWAUKEE, WI 53224\n...
# 807  Transformation  2751 SOUTH LENOX ST\nMILWAUKEE, WI 53207\n(42....
# 808         Closure  227 WEST PLACEEASANT ST\nMILWAUKEE, WI 53212\n...
# 809  Transformation  1515 WEST LAPHAM BLVD\nMILWAUKEE, WI 53204\n(4...
# 810         Restart  1011 WEST CENTER ST\nMILWAUKEE, WI 53206\n(43....
# 811         Closure  2525 NORTH SHERMAN BLVD\nMILWAUKEE, WI 53210\n...
# 812  Transformation  700 SOUTH FOURTH ST\nMILWAUKEE, WI 53204\n(43....
# 813  Transformation  8130 COUROUTE ST\nHAMLIN, WV 25523\n(38.2787, ...
# 814  Transformation  1 WARRIOR WAY\nBELLE, WV 25015\n(38.2134, -81....
# 815  Transformation  ROUTE 2 BOX 35-D\nWEST UNION, WV 26456\n(39.30...
# 816  Transformation  950 MOUNT VIEW RD\nWELCH, WV 24801\n(37.4037, ...
# 817  Transformation  ROUTE 1 BOX 112A\nWEST HAMLIN, WV 25571\n(38.2...
# 818  Transformation  4001 SALINAS DR\nCHARLESTON, WV 25306\n(38.301...
# 819  Transformation  250 EAST RD\nMARTINSBURG, WV 25401\n(39.4724, ...
# 820  Transformation  ROUTE 80\nAVONDALE, WV 24811\n(37.4021, -81.7854)
# 821  Transformation  812 PARK AVE\nCHARLESTON, WV 25302\n(38.3671, ...
# 822  Transformation  FIRST AND BRANNEN\nEAST BANK, WV 25067\n(38.21...
# 823  Transformation  1511 DIVISION ST EXT\nPARKERSBURG, WV 26101\n(...
# 824  Transformation  700 STATE ROUTE 10 NORTH\nBRANCHLAND, WV 25506...
# 825  Transformation  1 JOHN ST\nCEDAR GROVE, WV 25039\n(38.2174, -8...
# 826  Transformation  110 HIGH SCHOOL DR\nMOUNT HOPE, WV 25880\n(37....
# 827  Transformation  9538 CLAY RD\nLEFT HAND, WV 25251\n(38.6188, -...
# 828  Transformation  2201 MORRIE AVE\nCHEYENNE, WY 82001\n(41.1423,...
# 829  Transformation    US HWY 72\nHANNA, WY 82327\n(41.8723, -106.548)
# 830  Transformation  140 EAST K ST\nCASPER, WY 82601\n(42.861, -106...
#
# [831 rows x 7 columns]

# %% [markdown]
# ### So our dataset has 7 columns: school name, city, state, district, grant amount, model selected, and location.

# %% [markdown]
# ### Our employer is comparing these schools based on the amount they are granted, which is our most interesting variable, as its the one that appears to be calcuated from values in the other columns. If we are to draw a conclusion that our employer can use, we need to assume that the grant amount is a dependent variable influneced by the independent variables in other columns.

# %% [markdown]
# ### I'm going to look at a few basic calculations just to get a feel for my data.

# %%
data.shape
# Out:
# (831, 7)

# %% [markdown]
# ### Confirmed 7 columns = confirmed 7 variables. Also we have 831 total observations for schools.

# %%
data.describe()
# Out:
#                        School Name          City State         District Name  \
# count                          831           831   831                   831
# unique                         821           424    50                   421
# top     MOUNT PLEASANT HIGH SCHOOL  PHILADELPHIA    CA  PHILADELPHIA CITY SD
# freq                             2            29    92                    27
#
#        2010/11/Award Amount  Model Selected  \
# count                   757             825
# unique                  651               4
# top                   $2.00  Transformation
# freq                     17             608
#
#                                                  Location
# count                                                 831
# unique                                                823
# top     6941 NORTH CENTRAL ST\nPORTLAND, OR 97203\n(45...
# freq                                                    3

# %% [markdown]
# ### It appears we might have a few duplicates in our midst, but to make sure, we should review our data. Pandas allows us to search for duplicates with a single command.

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 801    False
# 802    False
# 803    False
# 804    False
# 805    False
# 806    False
# 807    False
# 808    False
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# 823    False
# 824    False
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# 830    False
# Length: 831, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                                           School Name               City  \
# 0                   HOGARTH KINGEEKUK MEMORIAL SCHOOL           SAVOONGA
# 1                                     AKIACHAK SCHOOL           AKIACHAK
# 2                                      GAMBELL SCHOOL            GAMBELL
# 3                                BURCHELL HIGH SCHOOL            WASILLA
# 4                                        AKIAK SCHOOL              AKIAK
# 5                                      MIDVALLEY HIGH            WASILLA
# 6                                     TULUKSAK SCHOOL           TULUKSAK
# 7                         CAPITOL HEIGHTS JR HIGH SCH         MONTGOMERY
# 8                               LOWNDES CO MIDDLE SCH       FORT DEPOSIT
# 9                                  CENTRAL MIDDLE SCH           ROCKFORD
# 10                            BELLINGRATH JR HIGH SCH         MONTGOMERY
# 11                              HAYNEVILLE MIDDLE SCH         HAYNEVILLE
# 12                               SOUTHLAWN MIDDLE SCH         MONTGOMERY
# 13                            CONTINUOUS LEARNING CTR             MOBILE
# 14                            JACKSON-STEELE ELEM SCH         HAYNEVILLE
# 15                                MCINTYRE MIDDLE SCH         MONTGOMERY
# 16                                JOHN ESSEX HIGH SCH          DEMOPOLIS
# 17                                   CALHOUN HIGH SCH        LETOHATCHEE
# 18                              OSCEOLA MIDDLE SCHOOL            OSCEOLA
# 19                                   HALL HIGH SCHOOL        LITTLE ROCK
# 20                            ROSE CITY MIDDLE SCHOOL  NORTH LITTLE ROCK
# 21                           TRUSTY ELEMENTARY SCHOOL         FORT SMITH
# 22                              J.A. FAIR HIGH SCHOOL        LITTLE ROCK
# 23                                OSCEOLA HIGH SCHOOL            OSCEOLA
# 24                           CLOVERDALE MIDDLE SCHOOL        LITTLE ROCK
# 25                          GADSDEN ELEMENTARY SCHOOL            GADSDEN
# 26                            EAST VALLEY HIGH SCHOOL               MESA
# 27                           CRITTENTON YOUTH ACADEMY            PHOENIX
# 28                               ALCHESAY HIGH SCHOOL         WHITERIVER
# 29                             SAN CARLOS HIGH SCHOOL         SAN CARLOS
# ..                                                ...                ...
# 801                          WASHINGTON MIDDLE SCHOOL             YAKIMA
# 802  FOSTER & WILLIAMS HIGH SCHOOL OF THE VISUAL ARTS          MILWAUKEE
# 803                                       DUBOIS HIGH          MILWAUKEE
# 804                                       CUSTER HIGH          MILWAUKEE
# 805                     JAMES MADISON ACADEMIC CAMPUS          MILWAUKEE
# 806                                      VINCENT HIGH          MILWAUKEE
# 807                                     BAY VIEW HIGH          MILWAUKEE
# 808       DOWNTOWN INSTITUTE OF ARTS & LETTERS (DIAL)          MILWAUKEE
# 809                               SOUTH DIVISION HIGH          MILWAUKEE
# 810         MILWAUKEE AFRICAN AMERICAN IMMERSION HIGH          MILWAUKEE
# 811                WHS LAW EDUCATION & PUBLIC SERVICE          MILWAUKEE
# 812                           BRADLEY TECHNOLOGY HIGH          MILWAUKEE
# 813                                       HAMLIN PK-8             HAMLIN
# 814                             RIVERSIDE HIGH SCHOOL              BELLE
# 815                DODDRIDGE COUNTY ELEMENTARY SCHOOL         WEST UNION
# 816                            MOUNT VIEW HIGH SCHOOL              WELCH
# 817                            WEST HAMLIN ELEMENTARY        WEST HAMLIN
# 818                          MALDEN ELEMENTARY SCHOOL         CHARLESTON
# 819                   MARTINSBURG NORTH MIDDLE SCHOOL        MARTINSBURG
# 820                         SANDY RIVER MIDDLE SCHOOL           AVONDALE
# 821                   STONEWALL JACKSON MIDDLE SCHOOL         CHARLESTON
# 822                           EAST BANK MIDDLE SCHOOL          EAST BANK
# 823                        FRANKLIN ELEMENTARY CENTER        PARKERSBURG
# 824                               GUYAN VALLEY MIDDLE         BRANCHLAND
# 825                         CEDAR GROVE MIDDLE SCHOOL        CEDAR GROVE
# 826                            MOUNT HOPE HIGH SCHOOL         MOUNT HOPE
# 827                           GEARY ELEMENTARY SCHOOL          LEFT HAND
# 828                               TRIUMPH HIGH SCHOOL           CHEYENNE
# 829                     HEM JUNIOR/SENIOR HIGH SCHOOL              HANNA
# 830                             ROOSEVELT HIGH SCHOOL             CASPER
#
#     State                                  District Name 2010/11/Award Amount  \
# 0      AK                  BERING STRAIT SCHOOL DISTRICT           $471014.00
# 1      AK                         YUPIIT SCHOOL DISTRICT           $520579.00
# 2      AK                  BERING STRAIT SCHOOL DISTRICT           $449592.00
# 3      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $641184.00
# 4      AK                         YUPIIT SCHOOL DISTRICT           $399686.00
# 5      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $697703.00
# 6      AK                         YUPIIT SCHOOL DISTRICT           $427658.00
# 7      AL                              MONTGOMERY COUNTY           $110544.00
# 8      AL                                 LOWNDES COUNTY            $12973.00
# 9      AL                                   COOSA COUNTY           $199828.00
# 10     AL                              MONTGOMERY COUNTY           $165903.00
# 11     AL                                 LOWNDES COUNTY           $121657.00
# 12     AL                              MONTGOMERY COUNTY           $914557.00
# 13     AL                                  MOBILE COUNTY           $198953.00
# 14     AL                                 LOWNDES COUNTY           $118394.00
# 15     AL                              MONTGOMERY COUNTY           $143238.00
# 16     AL                                 MARENGO COUNTY           $151116.00
# 17     AL                                 LOWNDES COUNTY           $163619.00
# 18     AR                        OSCEOLA SCHOOL DISTRICT           $665000.00
# 19     AR                    LITTLE ROCK SCHOOL DISTRICT           $198728.00
# 20     AR                 N. LITTLE ROCK SCHOOL DISTRICT           $991451.00
# 21     AR                     FORT SMITH SCHOOL DISTRICT           $990135.00
# 22     AR                    LITTLE ROCK SCHOOL DISTRICT           $197012.00
# 23     AR                        OSCEOLA SCHOOL DISTRICT           $695000.00
# 24     AR                    LITTLE ROCK SCHOOL DISTRICT           $198783.00
# 25     AZ                    GADSDEN ELEMENTARY DISTRICT           $847003.00
# 26     AZ                         LEGACY EDUCATION GROUP           $381512.00
# 27     AZ  FLORENCE CRITTENTON SERVICES OF ARIZONA  INC.           $915959.00
# 28     AZ                    WHITERIVER UNIFIED DISTRICT           $812195.00
# 29     AZ                    SAN CARLOS UNIFIED DISTRICT           $928654.00
# ..    ...                                            ...                  ...
# 801    WA                         YAKIMA SCHOOL DISTRICT           $115268.00
# 802    WI                      MILWAUKEE SCHOOL DISTRICT             $5000.00
# 803    WI                      MILWAUKEE SCHOOL DISTRICT             $5000.00
# 804    WI                      MILWAUKEE SCHOOL DISTRICT           $650093.00
# 805    WI                      MILWAUKEE SCHOOL DISTRICT           $749320.00
# 806    WI                      MILWAUKEE SCHOOL DISTRICT           $928024.00
# 807    WI                      MILWAUKEE SCHOOL DISTRICT           $134909.00
# 808    WI                      MILWAUKEE SCHOOL DISTRICT             $5000.00
# 809    WI                      MILWAUKEE SCHOOL DISTRICT           $124643.00
# 810    WI                      MILWAUKEE SCHOOL DISTRICT           $567905.00
# 811    WI                      MILWAUKEE SCHOOL DISTRICT             $5000.00
# 21   Transformation  3300 HARRIS AVE\nFORT SMITH, AR 72904\n(35.412...
# 22   Transformation  13420 DAVID O DODD RD\nLITTLE ROCK, AR 72210\n...
# 23   Transformation  2800 WEST SEMMES\nOSCEOLA, AR 72370\n(35.7053,...
# 24   Transformation  6300 HINKSON RD\nLITTLE ROCK, AR 72209\n(34.67...
# 25   Transformation  18745 SOUTH GADSDEN ST\nGADSDEN, AZ 85336\n(32...
# 26       Turnaround  7420 EAST MAIN ST\nMESA, AZ 85207\n(33.4155, -...
# 27       Turnaround  715 WEST MARIPOSA ST\nPHOENIX, AZ 85013\n(33.5...
# 28   Transformation  200 FALCON WAY\nWHITERIVER, AZ 85941\n(33.8252...
# 29   Transformation  SAN CARLOS AVE\nSAN CARLOS, AZ 85550\n(33.3514...
# ..              ...                                                ...
# 801  Transformation  510 SOUTH 9TH ST\nYAKIMA, WA 98901\n(46.5986, ...
# 802         Closure  6700 NORTH 80TH ST\nMILWAUKEE, WI 53223\n(43.1...
# 803         Closure  4141 NORTH 64TH ST\nMILWAUKEE, WI 53216\n(43.0...
# 804         Restart  5075 NORTH SHERMAN BLVD\nMILWAUKEE, WI 53209\n...
# 805  Transformation  8135 WEST FLORIST AVE\nMILWAUKEE, WI 53218\n(4...
# 806  Transformation  7501 NORTH GRANVILLE RD\nMILWAUKEE, WI 53224\n...
# 807  Transformation  2751 SOUTH LENOX ST\nMILWAUKEE, WI 53207\n(42....
# 808         Closure  227 WEST PLACEEASANT ST\nMILWAUKEE, WI 53212\n...
# 809  Transformation  1515 WEST LAPHAM BLVD\nMILWAUKEE, WI 53204\n(4...
# 810         Restart  1011 WEST CENTER ST\nMILWAUKEE, WI 53206\n(43....
# 811         Closure  2525 NORTH SHERMAN BLVD\nMILWAUKEE, WI 53210\n...
# 812  Transformation  700 SOUTH FOURTH ST\nMILWAUKEE, WI 53204\n(43....
# 813  Transformation  8130 COUROUTE ST\nHAMLIN, WV 25523\n(38.2787, ...
# 814  Transformation  1 WARRIOR WAY\nBELLE, WV 25015\n(38.2134, -81....
# 815  Transformation  ROUTE 2 BOX 35-D\nWEST UNION, WV 26456\n(39.30...
# 816  Transformation  950 MOUNT VIEW RD\nWELCH, WV 24801\n(37.4037, ...
# 817  Transformation  ROUTE 1 BOX 112A\nWEST HAMLIN, WV 25571\n(38.2...
# 818  Transformation  4001 SALINAS DR\nCHARLESTON, WV 25306\n(38.301...
# 819  Transformation  250 EAST RD\nMARTINSBURG, WV 25401\n(39.4724, ...
# 820  Transformation  ROUTE 80\nAVONDALE, WV 24811\n(37.4021, -81.7854)
# 821  Transformation  812 PARK AVE\nCHARLESTON, WV 25302\n(38.3671, ...
# 822  Transformation  FIRST AND BRANNEN\nEAST BANK, WV 25067\n(38.21...
# 823  Transformation  1511 DIVISION ST EXT\nPARKERSBURG, WV 26101\n(...
# 824  Transformation  700 STATE ROUTE 10 NORTH\nBRANCHLAND, WV 25506...
# 825  Transformation  1 JOHN ST\nCEDAR GROVE, WV 25039\n(38.2174, -8...
# 826  Transformation  110 HIGH SCHOOL DR\nMOUNT HOPE, WV 25880\n(37....
# 827  Transformation  9538 CLAY RD\nLEFT HAND, WV 25251\n(38.6188, -...
# 828  Transformation  2201 MORRIE AVE\nCHEYENNE, WY 82001\n(41.1423,...
# 829  Transformation    US HWY 72\nHANNA, WY 82327\n(41.8723, -106.548)
# 830  Transformation  140 EAST K ST\nCASPER, WY 82601\n(42.861, -106...
#
# [831 rows x 7 columns]

# %% [markdown]
# ### Since no entries were dropped, I'm going to assume that some schools just so happen to be named the same. Either that, or someone enterred their school name twice, but accidentally typoed something the second time because they are so skillful with accidentally leaving their hand on the keyboard without realizing it.

# %% [markdown]
# ### Our data also has a few entries that don't record a grant amount. If these missing values were recorded in a column that was independent and unnecesary to our conlcusions then we would probably have to fill them in ourselves. However, since we're looking for patterns in the "grant amount" column itself, those empty rows aren't really that useful to us. We can just get rid of any of the columns with missing values, and we'll still have plenty of entries that we can use to find trends in our data.

# %%
data = data[pd.notnull(data['2010/11/Award Amount'])]

# %%
data.describe()
# Out:
#              School Name          City State         District Name  \
# count                757           757   757                   757
# unique               748           382    46                   372
# top     EAST HIGH SCHOOL  PHILADELPHIA    CA  PHILADELPHIA CITY SD
# freq                   2            29    92                    27
#
#        2010/11/Award Amount  Model Selected  \
# count                   757             757
# unique                  651               4
# top                   $2.00  Transformation
# freq                     17             543
#
#                                                  Location
# count                                                 757
# unique                                                749
# top     6941 NORTH CENTRAL ST\nPORTLAND, OR 97203\n(45...
# freq                                                    3

# %% [markdown]
# ### We still have 757 entries that we can analyze using graphics resources such as plot.ly.

# %%
data.loc[:,"2010/11/Award Amount"].mean
# Out:
# <bound method Series.mean of 0      $471014.00
# 1      $520579.00
# 2      $449592.00
# 3      $641184.00
# 4      $399686.00
# 5      $697703.00
# 6      $427658.00
# 7      $110544.00
# 8       $12973.00
# 9      $199828.00
# 10     $165903.00
# 11     $121657.00
# 12     $914557.00
# 13     $198953.00
# 14     $118394.00
# 15     $143238.00
# 16     $151116.00
# 17     $163619.00
# 18     $665000.00
# 19     $198728.00
# 20     $991451.00
# 21     $990135.00
# 22     $197012.00
# 23     $695000.00
# 24     $198783.00
# 25     $847003.00
# 26     $381512.00
# 27     $915959.00
# 28     $812195.00
# 29     $928654.00
#           ...
# 801    $115268.00
# 802      $5000.00
# 803      $5000.00
# 804    $650093.00
# 805    $749320.00
# 806    $928024.00
# 807    $134909.00
# 808      $5000.00
# 809    $124643.00
# 810    $567905.00
# 811      $5000.00
# 812      $1202.00
# 813    $258600.00
# 814    $481900.00
# 815    $464200.00
# 816    $450000.00
# 817    $156660.00
# 818    $217598.00
# 819    $461690.00
# 820    $370000.00
# 821    $241211.00
# 822    $314618.00
# 823    $389906.00
# 824    $341250.00
# 825    $211271.00
# 826    $342189.00
# 827    $260000.00
# 828    $297300.00
# 829    $274000.00
# 830    $431382.00
# Name: 2010/11/Award Amount, Length: 757, dtype: object>

# %% [markdown]
# ### This gives us information, but it doesn't allow us to find any trends in our data. Plot.ly can help with this.

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
plotly.tools.set_credentials_file(username='ns248', api_key='6XA3DRSaSVsboozfFxZF')
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# 
"$666136.00", "$108015.00", "$660025.00", "$617334.00", "$737977.00", "$618351.00", "$515138.00", "$713746.00", "$759293.00", "$736088.00", "$440823.00", "$647552.00", "$500000.00", "$500000.00", "$267620.00", "$737052.00", "$636816.00", "$10496.00", "$276644.00", "$698427.00", "$652965.00", "$796553.00", "$567148.00", "$759293.00", "$784700.00", "$651787.00", "$627776.00", "$676989.00", "$500000.00", "$407497.00", "$759293.00", "$713451.00", "$759293.00", "$251911.00", "$759293.00", "$644329.00", "$660025.00", "$344819.00", "$518789.00", "$652792.00", "$742472.00", "$713746.00", "$697645.00", "$997322.00", "$628602.00", "$635832.00", "$500000.00", "$500000.00", "$369914.00", "$759293.00", "$633527.00", "$506738.00", "$115158.00", "$955121.00", "$115976.00", "$11667.00", "$185136.00", "$144427.00", "$942738.00", "$107896.00", "$788579.00", "$146453.00", "$139306.00", "$122676.00", "$147015.00",  ...

# %% [markdown]
# ### Cool, so our data has a ton of entries where the grant size is either close to 0 dollars or bettwen 100,000 and 200,000 dollars. Maybe we can find out whether schools with certain locations recieve consistently variable amounts of grant money.

# %%
data.dtypes # I do this because we're going to need to convert one of our varaibles to a different type
# Out:
# School Name             object
# City                    object
# State                   object
# District Name           object
# 2010/11/Award Amount    object
# Model Selected          object
# Location                object
# dtype: object

# %%
data['2010/11/Award Amount'] = data['2010/11/Award Amount'].str.replace('$', '')

# %%
data[['2010/11/Award Amount']] = data[['2010/11/Award Amount']].astype(float) #this converts the monetary string into a number we can graph

# %%
data.groupby('State')['2010/11/Award Amount'].median()
# Out:
# State
# AK    471014.0
# AL    151116.0
# AR    665000.0
# AZ    728696.0
# CA    169199.5
# CO    619609.0
# CT    590000.0
# DC    481370.0
# DE    651608.0
# FL    652965.0
# GA    142540.0
# IA        18.0
# ID    248340.0
# IL    175105.0
# IN    199941.0
# KS    144190.5
# KY    437283.0
# MA    665108.0
# MD    773922.0
# MI    198255.0
# MN    561111.0
# MO    379991.5
# MS     70576.0
# MT    259182.0
# NC    693605.0
# ND    418574.0
# NE    510953.0
# NH    346179.0
# NJ    163269.0
# NM        15.0
# NV    500345.0
# NY    117372.0
# OH    451750.0
# OK    134920.0
# OR    616667.0
# PA    483332.5
# SC    579145.0
# SD    265445.0
# TN    290710.5
# UT    549444.0
# VA    499793.0
# VT    250173.5
# WA    170768.5
# WI    124643.0
# WV    341250.0
# WY    297300.0
# Name: 2010/11/Award Amount, dtype: float64

# %% [markdown]
# ### Well those semantics took way too long to figure out. Had to replace the dollar signs in order to convert the grant amounts to floats. Anyway, now we can accurately find numerical statistics for the amount column.

# %%
dataBar = [go.Bar(x=data['State'], y=data['2010/11/Award Amount'])]

# %%
iplot(dataBar)
# Out:
# <div id="3dc795d5-82f5-42e7-8040-4ebecbac6eb2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3dc795d5-82f5-42e7-8040-4ebecbac6eb2", [{"x": ["AK", "AK", "AK", "AK", "AK", "AK", "AK", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AR", "AR", "AR", "AR", "AR", "AR", "AR", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "AZ", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CO", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "CT", "DC", "DC", "DC", "DC", "DC", "DC", "DC", "DC", "DC", "DC", "DE", "DE", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "FL", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "GA", "IA", "IA", "IA", "IA", "ID", "ID", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "IL", "IN", "IN", "IN", "IN", "IN", "IN", "IN", "KS", "KS", "KS", "KS", "KS", "KS", "KY", "KY", "KY", "KY", "KY", "KY", "KY", "KY", "KY", "KY", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MA", "MD", "MD", "MD", "MD", "MD", "MD", "MD", "MD", "MD", "MD", "MD", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MI", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MN", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MO", "MS", "MS", "MS", "MS", "MS", "MS", "MS", "MS", "MT", "MT", "MT", "MT", "MT", "MT", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "NC", "ND", "NE", "NE", "NE", "NE", "NE", "NE", "NE", "NH", "NH", "NH", "NH", "NH", "NH", "NH", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NJ", "NM", "NM", "NM", "NM", "NM", "NM", "NM", "NM", "NM", "NV", "NV", "NV", "NV", "NV", "NV", "NV", "NV", "NV", "NV", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "NY", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OH", "OK", "OK", "OK", "OK", "OK", "OK", "OK", "OK", "OK", "OK", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA", "PA ...

# %% [markdown]
# ### which gets us total amount of grant money per state. But since this doesn't take into account how many schools recieve money per state, and states with more schools represented will probably recieve more money, we need to take the average instead and incorporate that into our chart.

# %%
dataAver = data.groupby(['State']).mean()

# %% [markdown]
# ### I used groupby to get the average grant amount of a school per state. Now let's plot this.

# %%
dataAverSort=dataAver.sort_values('2010/11/Award Amount')
dataAverSort
# Out:
#        2010/11/Award Amount
# State
# MS            156269.125000
# NJ            179858.583333
# IA            190308.750000
# AL            209162.000000
# KS            211776.666667
# NM            219463.333333
# IL            219711.000000
# CA            220508.956522
# NY            226754.040000
# ID            248340.000000
# SD            265445.000000
# VT            275048.300000
# OK            277048.500000
# WI            288736.000000
# IN            313109.571429
# MT            326948.333333
# WV            330739.533333
# WY            334227.333333
# GA            342035.730769
# WA            364956.166667
# NH            380229.142857
# MI            389058.214286
# MO            412973.343750
# TN            416475.666667
# ND            418574.000000
# DC            419933.900000
# OH            436193.885714
# VA            444943.888889
# OR            482669.000000
# PA            488244.948276
# NV            499156.800000
# KY            502593.800000
# AK            515345.142857
# CO            534643.789474
# MD            548507.000000
# AR            562301.285714
# CT            574366.928571
# NE            582582.714286
# NC            588136.434783
# SC            593300.368421
# UT            607375.000000
# FL            607589.563380
# MN            612284.052632
# MA            620105.500000
# DE            651608.000000
# AZ            693755.000000

# %%
dataAverSortN=dataAverSort #creating an alternate array so I can graph with State on the x-axis

# %%
dataAverSortN.index.name = 'State'
dataAverSortN.reset_index(inplace=True)

# %%
iplot(
    go.Figure(
        data = [
            go.Bar(x=dataAverSortN['State'], y=dataAverSort['2010/11/Award Amount'])],
    
        layout = go.Layout(
            height = 500,
            title = 'School Grant Size per State',
            xaxis=dict(
            title='State'),
            yaxis=dict(
            title='Average Amount of Grant ($)')
        )
))
# Out:
# <div id="0975a417-f53f-4247-85d7-638261b09ad2" style="height: 500px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0975a417-f53f-4247-85d7-638261b09ad2", [{"x": ["MS", "NJ", "IA", "AL", "KS", "NM", "IL", "CA", "NY", "ID", "SD", "VT", "OK", "WI", "IN", "MT", "WV", "WY", "GA", "WA", "NH", "MI", "MO", "TN", "ND", "DC", "OH", "VA", "OR", "PA", "NV", "KY", "AK", "CO", "MD", "AR", "CT", "NE", "NC", "SC", "UT", "FL", "MN", "MA", "DE", "AZ"], "y": [156269.125, 179858.58333333334, 190308.75, 209162.0, 211776.66666666666, 219463.33333333334, 219711.0, 220508.95652173914, 226754.04, 248340.0, 265445.0, 275048.3, 277048.5, 288736.0, 313109.5714285714, 326948.3333333333, 330739.5333333333, 334227.3333333333, 342035.73076923075, 364956.1666666667, 380229.14285714284, 389058.21428571426, 412973.34375, 416475.6666666667, 418574.0, 419933.9, 436193.8857142857, 444943.8888888889, 482669.0, 488244.9482758621, 499156.8, 502593.8, 515345.14285714284, 534643.7894736842, 548507.0, 562301.2857142857, 574366.9285714285, 582582.7142857143, 588136.4347826086, 593300.3684210526, 607375.0, 607589.5633802817, 612284.052631579, 620105.5, 651608.0, 693755.0], "type": "bar", "uid": "b761e4e2-74ae-44c0-8d2e-34c992984e98"}], {"height": 500, "title": "School Grant Size per State", "xaxis": {"title": "State"}, "yaxis": {"title": "Average Amount of Grant ($)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){Plotly.Plots.resize(document.getElementById("0975a417-f53f-4247-85d7-638261b09ad2"));});</script>

# %% [markdown]
# ### And now we have graphed the average grant size per state! However we're also concerned about organizing by model type. Let's make a plot for this too. (At least this will have fewer columns)

# %%
dataInterAver = data.groupby(['Model Selected']).mean() #The inter stands for intervention, as in intervention model

# %%
dataInterAverSort=dataInterAver.sort_values('2010/11/Award Amount')
dataInterAverSort
# Out:
#                 2010/11/Award Amount
# Model Selected
# Closure                 75155.500000
# Turnaround             394100.581818
# Transformation         434116.062615
# Restart                503412.424242

# %%
dataInterAverSortN=dataInterAverSort #creating an alternate array again

# %%
dataInterAverSortN.index.name = 'Intervention Model'
dataInterAverSortN.reset_index(inplace=True) 
dataInterAverSortN
# Out:
#   Intervention Model  2010/11/Award Amount
# 0            Closure          75155.500000
# 1         Turnaround         394100.581818
# 2     Transformation         434116.062615
# 3            Restart         503412.424242

# %%
iplot(
    go.Figure(
        data = [
            go.Bar(x=dataInterAverSortN['Intervention Model'], y=dataInterAverSortN['2010/11/Award Amount'])],
    
        layout = go.Layout(
            height = 500,
            title = 'Average Grant Size per Intervention Model',
            xaxis=dict(
            title='Type of Intervention Model Used'),
            yaxis=dict(
            title='Avereage Amount of Grant ($)')
        )
))
# Out:
# <div id="203d3473-4146-4757-b9fa-311eae1ed0a2" style="height: 500px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("203d3473-4146-4757-b9fa-311eae1ed0a2", [{"x": ["Closure", "Turnaround", "Transformation", "Restart"], "y": [75155.5, 394100.58181818185, 434116.0626151013, 503412.42424242425], "type": "bar", "uid": "0a34404c-1781-4047-9694-35b20eba6716"}], {"height": 500, "title": "Average Grant Size per Intervention Model", "xaxis": {"title": "Type of Intervention Model Used"}, "yaxis": {"title": "Avereage Amount of Grant ($)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){Plotly.Plots.resize(document.getElementById("203d3473-4146-4757-b9fa-311eae1ed0a2"));});</script>

# %% [markdown]
# ### If we had more columns than this I'd probably try a few more graph calculations, but until I get more information I'm comfortable talking about the information I currently have.
